# %% [markdown]
# **Import all important Data**

# %%
#Data Analysis
import pandas as pd
import numpy as np

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Machine learning Libraries

# %% [markdown]
# Reading the CSV File for preprocessing

# %%
train_df = pd.read_csv('./Data/train.csv')
test_df = pd.read_csv('./Data/test.csv')

# %% [markdown]
# Understanding inconsistencies in the data and its contents

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# In the above table size = 891 but certain fields seem to be empty as they are less than maximum

# %% [markdown]
# **Understanding the Data and its contents** \
# Observe data skewness, std also percentiles need to be observed

# %%
train_df.describe(include = 'all')
# Out:
#         PassengerId    Survived      Pclass                         Name  \
# count    891.000000  891.000000  891.000000                          891
# unique          NaN         NaN         NaN                          891
# top             NaN         NaN         NaN  Hocking, Mr. Richard George
# freq            NaN         NaN         NaN                            1
# mean     446.000000    0.383838    2.308642                          NaN
# std      257.353842    0.486592    0.836071                          NaN
# min        1.000000    0.000000    1.000000                          NaN
# 25%      223.500000    0.000000    2.000000                          NaN
# 50%      446.000000    0.000000    3.000000                          NaN
# 75%      668.500000    1.000000    3.000000                          NaN
# max      891.000000    1.000000    3.000000                          NaN
#
#          Sex         Age       SibSp       Parch    Ticket        Fare  \
# ...

# %% [markdown]
# Understand binary data
# * **Survived** 38% survived according to the data
# * **Parch** 33% people had either parents and children on board(percentile 77)
# * **SibSp** 31% people had siblings or spouse on board (percentile-69)

# %%
train_df.describe(percentiles=[.61, .62,0.76,.77,0.8, .68,.69])
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 61%     543.900000    0.000000    3.000000   32.000000    0.000000
# 62%     552.800000    1.000000    3.000000   32.000000    0.000000
# 68%     606.200000    1.000000    3.000000   35.000000    0.000000
# 69%     615.100000    1.000000    3.000000   35.000000    1.000000
# 76%     677.400000    1.000000    3.000000   39.000000    1.000000
# 77%     686.300000    1.000000    3.000000   39.000000    1.000000
# 80%     713.000000    1.000000    3.000000   41.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
# ...

# %% [markdown]
# * **Age** Number pattern must be determined but only a few people survived
# * **Fare** fare seems to be constant but there is a drastic increase in price of 10% passenger

# %%
train_df.describe(percentiles=[.1, .2, .3, .4, .5, .6, .7, .8, .9,.97,.98, .99])
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 10%      90.000000    0.000000    1.000000   14.000000    0.000000
# 20%     179.000000    0.000000    1.000000   19.000000    0.000000
# 30%     268.000000    0.000000    2.000000   22.000000    0.000000
# 40%     357.000000    0.000000    2.000000   25.000000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 60%     535.000000    0.000000    3.000000   31.800000    0.000000
# 70%     624.000000    1.000000    3.000000   36.000000    1.000000
# 80%     713.000000    1.000000    3.000000   41.000000    1.000000
# 90%     802.000000    1.000000    3.000000   50.000000    1.000000
# ...

# %%
train_df.describe(include=['O'])
# Out:
#                                Name   Sex    Ticket    Cabin Embarked
# count                           891   891       891      204      889
# unique                          891     2       681      147        3
# top     Hocking, Mr. Richard George  male  CA. 2343  B96 B98        S
# freq                              1   577         7        4      644

# %%
train_df[['Pclass', 'Survived']].groupby(['Pclass'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#    Pclass  Survived
# 0       1  0.629630
# 1       2  0.472826
# 2       3  0.242363

# %%
train_df[["Sex", "Survived"]].groupby(['Sex'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#       Sex  Survived
# 0  female  0.742038
# 1    male  0.188908

# %%
train_df[["SibSp", "Survived"]].groupby(['SibSp'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#    SibSp  Survived
# 1      1  0.535885
# 2      2  0.464286
# 0      0  0.345395
# 3      3  0.250000
# 4      4  0.166667
# 5      5  0.000000
# 6      8  0.000000

# %%
train_df[["Parch", "Survived"]].groupby(['Parch'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#    Parch  Survived
# 3      3  0.600000
# 1      1  0.550847
# 2      2  0.500000
# 0      0  0.343658
# 5      5  0.200000
# 4      4  0.000000
# 6      6  0.000000

# %%
g = sns.FacetGrid(train_df, col='Survived')
g.map(plt.hist, 'Age', bins=20)

# %%
grid = sns.FacetGrid(train_df, col='Survived', row='Pclass')
grid.map(plt.hist, 'Age', bins=20)
grid.add_legend();
